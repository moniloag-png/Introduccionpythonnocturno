# %% [markdown]
# ![logo itq](img/imgitq.jpeg)
#
# ## Tercer Módulo-Python, Pandas_2
#
# ![logo python](img/imgpython.jpeg)
#
# *Mónica Guano*

# %%
import pandas as pd
import numpy as np

# %%
pd.__version__
# Out:
# '2.3.3'

# %% [markdown]
# # Operaciones en pandas

# %% [markdown]
# #### Búsqueda

# %%
rand_matrix = np.random.randint(6,size=(2,3))
frame = pd.DataFrame(rand_matrix , columns=list('ABC'))
display(frame)
# Out:
#    A  B  C
# 0  1  2  1
# 1  0  4  3

# %%
# buscando columnas (DataFrame como dic, busca en claves)
'A' in frame
# Out:
# True

# %%
# buscando valores
display(frame.isin([3,2])) # --> mask de respuesta (valores que son 3 o 2)
# Out:
#        A      B      C
# 0  False   True  False
# 1  False  False   True

# %%
# Contar el número de ocurrencias
print(frame.isin([4]).values.sum())
display(frame.isin([4])) #devuelve una mask con valores true si el elemento es 4
print(frame.isin([4]).values)
type(frame.isin([4]).values) # pandas es una capa alrededor de numpy
# Out:
# 1
#        A      B      C
# 0  False  False  False
# 1  False   True  False
# [[False False False]
#  [False  True False]]
# numpy.ndarray

# %%
# Cuántos valores son >= 2
mask = frame >= 2
print(mask.values.sum())
display(mask)
# Out:
# 3
#        A     B      C
# 0  False  True  False
# 1  False  True   True

# %% [markdown]
# #### Ordenación

# %%
from random import shuffle

rand_matrix = np.random.randint(20,size=(5,4))

indices = list(range(5))
shuffle(indices) # mezcla indices

frame = pd.DataFrame(rand_matrix , columns=list('DACB'), index=indices)
display(frame)
# Out:
#     D   A   C   B
# 4  18  17   6  15
# 3   0   7   5   0
# 2  18   9  17  19
# 1  15  14  18  13
# 0  19  19   6  18

# %%
# ordenar por índice
display(frame.sort_index(ascending=False))
display(frame)
# Out:
#     D   A   C   B
# 4  18  17   6  15
# 3   0   7   5   0
# 2  18   9  17  19
# 1  15  14  18  13
# 0  19  19   6  18
#     D   A   C   B
# 4  18  17   6  15
# 3   0   7   5   0
# 2  18   9  17  19
# 1  15  14  18  13
# 0  19  19   6  18

# %%
#ordenar por columna
display(frame.sort_index(axis=1, ascending=False))
# Out:
#     D   C   B   A
# 4  18   6  15  17
# 3   0   5   0   7
# 2  18  17  19   9
# 1  15  18  13  14
# 0  19   6  18  19

# %%
# ordenar filas por valor en columna
display(frame.sort_values(by='A', ascending=True))
# Out:
#     D   A   C   B
# 3   0   7   5   0
# 2  18   9  17  19
# 1  15  14  18  13
# 4  18  17   6  15
# 0  19  19   6  18

# %%
# ordenar columnas por valor en fila
display(frame.sort_values(by=1, axis=1, ascending=True))
# Out:
#     B   A   D   C
# 4  15  17  18   6
# 3   0   7   0   5
# 2  19   9  18  17
# 1  13  14  15  18
# 0  18  19  19   6

# %%
# ordenar por valor en columna y guardar cambios
frame.sort_values(by='A', ascending=False, inplace=True)
display(frame)
# Out:
#     D   A   C   B
# 0  19  19   6  18
# 4  18  17   6  15
# 1  15  14  18  13
# 2  18   9  17  19
# 3   0   7   5   0

# %% [markdown]
# #### Ranking
# - Construir un ranking de valores

# %%
display(frame)
# Out:
#     D   A   C   B
# 0  19  19   6  18
# 4  18  17   6  15
# 1  15  14  18  13
# 2  18   9  17  19
# 3   0   7   5   0

# %%
display(frame.rank(method='max', axis=1))
# Out:
#      D    A    C    B
# 0  4.0  4.0  1.0  2.0
# 4  4.0  3.0  1.0  2.0
# 1  3.0  2.0  4.0  1.0
# 2  3.0  1.0  2.0  4.0
# 3  2.0  4.0  3.0  2.0

# %%
# Imprimir, uno a uno, los valores de la columna 'C' de mayor a menor
for x in frame.sort_values(by='C', ascending=False)['C'].values:
    print(x)
# Out:
# 18
# 17
# 6
# 6
# 5

# %% [markdown]
# # Operaciones

# %% [markdown]
# Operaciones matemáticas entre objetos

# %%
matrixA = np.random.randint(100,size=(4,4))
matrixB = np.random.randint(100,size=(4,4))
frameA = pd.DataFrame(matrixA)
frameB = pd.DataFrame(matrixB)
display(frameA)
display(frameB)
# Out:
#     0   1   2   3
# 0  49  47  38  85
# 1  77  68  96  57
# 2  52  99  61  78
# 3  45  66  51  91
#     0   1   2   3
# 0   9  29  51  37
# 1  43  17  36  26
# 2  97  42  25  64
# 3  13  43  21   6

# %%
# a través de métodos u operadores
display(frameA + frameB == frameA.add(frameB))
display(frameA + frameB)
# Out:
#       0     1     2     3
# 0  True  True  True  True
# 1  True  True  True  True
# 2  True  True  True  True
# 3  True  True  True  True
#      0    1    2    3
# 0   58   76   89  122
# 1  120   85  132   83
# 2  149  141   86  142
# 3   58  109   72   97

# %%
display(frameB - frameA == frameB.sub(frameA))
display(frameB - frameA)
# Out:
#       0     1     2     3
# 0  True  True  True  True
# 1  True  True  True  True
# 2  True  True  True  True
# 3  True  True  True  True
#     0   1   2   3
# 0 -40 -18  13 -48
# 1 -34 -51 -60 -31
# 2  45 -57 -36 -14
# 3 -32 -23 -30 -85

# %%
# si los frames no son iguales, valor por defecto NaN
frameC = pd.DataFrame(np.random.randint(100,size=(3,3)))
display(frameA)
display(frameC)
display(frameC + frameA)
# Out:
#     0   1   2   3
# 0  49  47  38  85
# 1  77  68  96  57
# 2  52  99  61  78
# 3  45  66  51  91
#     0   1   2
# 0   8  72  18
# 1  74  31  24
# 2  68  91  95
#        0      1      2   3
# 0   57.0  119.0   56.0 NaN
# 1  151.0   99.0  120.0 NaN
# 2  120.0  190.0  156.0 NaN
# 3    NaN    NaN    NaN NaN

# %%
# se puede especificar el valor por defecto con el argumento fill_value
display(frameA.add(frameC, fill_value=0))
# Out:
#        0      1      2     3
# 0   57.0  119.0   56.0  85.0
# 1  151.0   99.0  120.0  57.0
# 2  120.0  190.0  156.0  78.0
# 3   45.0   66.0   51.0  91.0

# %% [markdown]
# Operadores aritméticos solo válidos en elementos aceptables

# %%
frameD = pd.DataFrame({0: ['a','b'],1:['d','f']})
display(frameD)
frameA - frameD
# Out:
#    0  1
# 0  a  d
# 1  b  f
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\ops\array_ops.py:218, in _na_arithmetic_op(left, right, op, is_cmp)
#     217 try:
# --> 218     result = func(left, right)
#     219 except TypeError:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:242, in evaluate(op, a, b, use_numexpr)
#     240     if use_numexpr:
#     241         # error: "None" not callable
# --> 242         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     243 return _evaluate_standard(op, op_str, a, b)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:131, in _evaluate_numexpr(op, op_str, a, b)
#     130 if result is None:
# --> 131     result = _evaluate_standard(op, op_str, a, b)
#     133 return result
#
# File ~\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:73, in _evaluate_standard(op, op_str, a, b)
#      72     _store_test_result(False)
# ---> 73 return op(a, b)
#
# TypeError: unsupported operand type(s) for -: 'int' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 3
#       1 frameD = pd.DataFrame({0: ['a','b'],1:['d','f']})
#       2 display(frameD)
# ----> 3 frameA - frameD
#
# File ~\anaconda3\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\arraylike.py:194, in OpsMixin.__sub__(self, other)
#     192 @unpack_zerodim_and_defer("__sub__")
#     193 def __sub__(self, other):
# --> 194     return self._arith_method(other, operator.sub)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:7927, in DataFrame._arith_method(self, other, op)
#    7925 def _arith_method(self, other, op):
#    7926     if self._should_reindex_frame_op(other, op, 1, None, None):
# -> 7927         return self._arith_method_with_reindex(other, op)
#    7929     axis: Literal[1] = 1  # only relevant for Series other case
#    7930     other = ops.maybe_prepare_scalar_for_op(other, (self.shape[axis],))
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:8059, in DataFrame._arith_method_with_reindex(self, right, op)
#    8057 new_left = left.iloc[:, lcols]
#    8058 new_right = right.iloc[:, rcols]
# -> 8059 result = op(new_left, new_right)
#    8061 # Do the join on the columns instead of using left._align_for_op
#    8062 #  to avoid constructing two potentially large/sparse DataFrames
#    8063 join_columns, _, _ = left.columns.join(
#    8064     right.columns, how="outer", level=None, return_indexers=True
#    8065 )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\arraylike.py:194, in OpsMixin.__sub__(self, other)
#     192 @unpack_zerodim_and_defer("__sub__")
#     193 def __sub__(self, other):
# --> 194     return self._arith_method(other, operator.sub)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:7935, in DataFrame._arith_method(self, other, op)
#    7932 self, other = self._align_for_op(other, axis, flex=True, level=None)
#    7934 with np.errstate(all="ignore"):
# -> 7935     new_data = self._dispatch_frame_op(other, op, axis=axis)
#    7936 return self._construct_result(new_data)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:7978, in DataFrame._dispatch_frame_op(self, right, func, axis)
#    7972     assert self.columns.equals(right.columns)
#    7973     # TODO: The previous assertion `assert right._indexed_same(self)`
#    7974     #  fails in cases with empty columns reached via
#    7975     #  _frame_arith_method_with_reindex
#    7976
#    7977     # TODO operate_blockwise expects a manager of the same type
# -> 7978     bm = self._mgr.operate_blockwise(
#    7979         # error: Argument 1 to "operate_blockwise" of "ArrayManager" has
#    7980         # incompatible type "Union[ArrayManager, BlockManager]"; expected
#    7981         # "ArrayManager"
#    7982         # error: Argument 1 to "operate_blockwise" of "BlockManager" has
#    7983         # incompatible type "Union[ArrayManager, BlockManager]"; expected
#    7984         # "BlockManager"
#    7985         right._mgr,  # type: ignore[arg-type]
#    7986         array_op,
#    7987     )
#    7988     return self._constructor_from_mgr(bm, axes=bm.axes)
#    7990 elif isinstance(right, Series) and axis == 1:
#    7991     # axis=1 means we want to operate row-by-row
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1530, in BlockManager.operate_blockwise(self, other, array_op)
#    1526 def operate_blockwise(self, other: BlockManager, array_op) -> BlockManager:
#    1527     """
#    1528     Apply array_op blockwise with another (aligned) BlockManager.
#    1529     """
# -> 1530     return operate_blockwise(self, other, array_op)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\ops.py:65, in operate_blockwise(left, right, array_op)
#      63 res_blks: list[Block] = []
#      64 for lvals, rvals, locs, left_ea, right_ea, rblk in _iter_block_pairs(left, right):
# ---> 65     res_values = array_op(lvals, rvals)
#      66     if (
#      67         left_ea
#      68         and not right_ea
#      69         and hasattr(res_values, "reshape")
#      70         and not is_1d_only_ea_dtype(res_values.dtype)
#      71     ):
#      72         res_values = res_values.reshape(1, -1)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\ops\array_ops.py:283, in arithmetic_op(left, right, op)
#     279     _bool_arith_check(op, left, right)  # type: ignore[arg-type]
#     281     # error: Argument 1 to "_na_arithmetic_op" has incompatible type
#     282     # "Union[ExtensionArray, ndarray[Any, Any]]"; expected "ndarray[Any, Any]"
# --> 283     res_values = _na_arithmetic_op(left, right, op)  # type: ignore[arg-type]
#     285 return res_values
#
# File ~\anaconda3\Lib\site-packages\pandas\core\ops\array_ops.py:227, in _na_arithmetic_op(left, right, op, is_cmp)
#     219 except TypeError:
#     220     if not is_cmp and (
#     221         left.dtype == object or getattr(right, "dtype", None) == object
#     222     ):
#    (...)    225         # Don't do this for comparisons, as that will handle complex numbers
#     226         #  incorrectly, see GH#32047
# --> 227         result = _masked_arith_op(left, right, op)
#     228     else:
#     229         raise
#
# File ~\anaconda3\Lib\site-packages\pandas\core\ops\array_ops.py:163, in _masked_arith_op(x, y, op)
#     161     # See GH#5284, GH#5035, GH#19448 for historical reference
#     162     if mask.any():
# --> 163         result[mask] = op(xrav[mask], yrav[mask])
#     165 else:
#     166     if not is_scalar(y):
#
# TypeError: unsupported operand type(s) for -: 'int' and 'str'

# %% [markdown]
# Operaciones entre Series y DataFrames

# %%
rand_matrix = np.random.randint(10, size=(3, 4))
df = pd.DataFrame(rand_matrix , columns=list('ABCD'))
display(df)

display(df.iloc[0])
display(type(df.iloc[0]))
# uso común, averiguar la diferencia entre una fila y el resto
display(df - df.iloc[0])
display(df.sub(df.iloc[0], axis=1))
# Por columnas cómo se restaría
display(df.sub(df['A'], axis=0))

# %% [markdown]
# pandas se basa en NumPy, np operadores binarios y unarios son aceptables
#
# | Tipo | Operación | Descripción |
# |:---------|:-----|:-----|
# | Unario | *abs* | Valor absoluto de cada elemento |
# | | *sqrt* | Raíz cuadrada de cada elemento |
# | | *exp* | e^x, siendo x cad elemento |
# | | *log, log10, log2* | Logaritmos en distintas bases de cada elemento |
# | | *sign* | Retorna el signo de cada elemento (-1 para negativo, 0 o 1 para positivo) |
# | | *ceil* | Redondea cada elemento por arriba |
# | | *floor* | Redondea cada elemento por abajo |
# | | *isnan* | Retorna si cada elemento es Nan |
# | | *cos, sin, tan* | Operaciones trigonométricas en cada elemento |
# | | *arccos, arcsin, arctan* | Inversas de operaciones trigonométricas en cada elemento |
# | Binario | *add* | Suma de dos arrays |
# | | *substract* | Resta de dos arrays |
# | | *multiply* | Multiplicación de dos arrays |
# | | *divide* | División de dos arrays |
# | | *maximum, minimum* | Retorna el valor máximo/mínimo de cada pareja de elementos |
# | | *equal, not_equal* | Retorna la comparación (igual o no igual) de cada pareja de elementos |
# | | *greater, greater_equal, less, less_equal* | Retorna la comparación (>, >=, <, <= respectivamente) de cada pareja de elementos |

# %% [markdown]
# Aplicación de funciones a medida con lambda

# %%
rand_matrix = np.random.randint(10, size=(3, 4))
frame = pd.DataFrame(rand_matrix , columns=list('ABCD'))
display(frame)

print(frame.apply(lambda x : x.max() - x.min(), axis = 1)) # diferencia por columna
# Out:
#    A  B  C  D
# 0  2  3  5  9
# 1  8  3  5  6
# 2  8  7  6  4
# 0    7
# 1    5
# 2    4
# dtype: int64

# %%
def max_min(x):
    return x.max() - x.min()

print(frame.apply(max_min, axis = 0)) # diferencia por columna
# Out:
# A    6
# B    4
# C    1
# D    5
# dtype: int64

# %%
# diferencia entre min y max por fila (no columna)
rand_matrix = np.random.randint(10, size=(3, 4))
frame = pd.DataFrame(rand_matrix , columns=list('ABCD'))
display(frame)

print(frame.apply(lambda x : x.max() - x.min(), axis = 1)) # diferencia por fila
# Out:
#    A  B  C  D
# 0  1  0  3  6
# 1  2  0  7  8
# 2  3  7  1  4
# 0    6
# 1    8
# 2    6
# dtype: int64

# %% [markdown]
# # Estadística descriptiva
# - Análisis preliminar de los datos
# - Para Series y DataFrame
#
# | Operación | Descripción |
# |:----------|:------------|
# | count | Número de valores no NaN |
# | describe | Conjunto de estadísticas sumarias|
# | min, max | Valores mínimo y máximo |
# | argmin, argmax | Índices posicionales del valor mínimo y máximo |
# | idxmin, idxmax | Índices semánticos del valor mínimo y máximo |
# | sum | Suma de los elementos |
# | mean | Media de los elementos |
# | median | Mediana de los elementos |
# | mad | Desviación absoluta media del valor medio |
# | var | Varianza de los elementos |
# | std | Desviación estándar de los elementos |
# | cumsum | Suma acumulada de los elementos |
# | diff | Diferencia aritmética de los elementos |

# %%
diccionario = { "nombre" : ["Marisa","Laura","Manuel", "Carlos"], "edad" : [34,34,11, 30], 
               "puntos" : [98,12,98,np.nan], "genero": ["F", "F", "M", "M"] }
frame = pd.DataFrame(diccionario)
display(frame)
display(frame.describe()) # datos generales de elementos
# Out:
#    nombre  edad  puntos genero
# 0  Marisa    34    98.0      F
# 1   Laura    34    12.0      F
# 2  Manuel    11    98.0      M
# 3  Carlos    30     NaN      M
#             edad     puntos
# count   4.000000   3.000000
# mean   27.250000  69.333333
# std    10.996211  49.652123
# min    11.000000  12.000000
# 25%    25.250000  55.000000
# 50%    32.000000  98.000000
# 75%    34.000000  98.000000
# max    34.000000  98.000000

# %%
# operadores básicos
print(frame.sum())

display(frame)
print(frame.sum(axis=1, numeric_only=True))
# Out:
# nombre    MarisaLauraManuelCarlos
# edad                          109
# puntos                      208.0
# genero                       FFMM
# dtype: object
#    nombre  edad  puntos genero
# 0  Marisa    34    98.0      F
# 1   Laura    34    12.0      F
# 2  Manuel    11    98.0      M
# 3  Carlos    30     NaN      M
# 0    132.0
# 1     46.0
# 2    109.0
# 3     30.0
# dtype: float64

# %%
frame.mean(numeric_only=True)
# Out:
# edad      27.250000
# puntos    69.333333
# dtype: float64

# %%
frame.cumsum()
# Out:
#                     nombre  edad  puntos genero
# 0                   Marisa    34    98.0      F
# 1              MarisaLaura    68   110.0     FF
# 2        MarisaLauraManuel    79   208.0    FFM
# 3  MarisaLauraManuelCarlos   109     NaN   FFMM

# %%
frame.count(axis=1)
# Out:
# 0    4
# 1    4
# 2    4
# 3    3
# dtype: int64

# %%
print(frame['edad'].std())
# Out:
# 10.996211468804457

# %%
frame['edad'].idxmax()
# Out:
# 0

# %%
frame['puntos'].idxmin()
# Out:
# 1

# %%
# frame con las filas con los valores maximos de una columna
print(frame['puntos'].max())

display(frame[frame['puntos'] == frame['puntos'].max()])
# Out:
# 98.0
#    nombre  edad  puntos genero
# 0  Marisa    34    98.0      F
# 2  Manuel    11    98.0      M

# %%
frame["ranking"] = frame["puntos"].rank(method='max')

# %%
display(frame)
# Out:
#    nombre  edad  puntos genero  ranking
# 0  Marisa    34    98.0      F      3.0
# 1   Laura    34    12.0      F      1.0
# 2  Manuel    11    98.0      M      3.0
# 3  Carlos    30     NaN      M      NaN

# %% [markdown]
# ## Agregaciones

# %%
display(frame)
df = frame.groupby('genero').count()
display(df)
# Out:
#    nombre  edad  puntos genero  ranking
# 0  Marisa    34    98.0      F      3.0
# 1   Laura    34    12.0      F      1.0
# 2  Manuel    11    98.0      M      3.0
# 3  Carlos    30     NaN      M      NaN
#         nombre  edad  puntos  ranking
# genero
# F            2     2       2        2
# M            2     2       1        1

# %%
# si es Nan descarta la fila
df = frame.groupby('puntos').count()
display(df)
# Out:
#         nombre  edad  genero  ranking
# puntos
# 12.0         1     1       1        1
# 98.0         2     2       2        2

# %%
display(frame.groupby('genero').mean(numeric_only=True))
# Out:
#         edad  puntos  ranking
# genero
# F       34.0    55.0      2.0
# M       20.5    98.0      3.0

# %%
display(frame.groupby('genero').max())
# Out:
#         nombre  edad  puntos  ranking
# genero
# F       Marisa    34    98.0      3.0
# M       Manuel    30    98.0      3.0

# %%
# funciones de agregación de varias columnas para obtener distintos estadísticos
display(frame.groupby('genero')[['edad', 'puntos']].aggregate(['min', 'mean', 'max']))
# Out:
#        edad           puntos
#         min  mean max    min  mean   max
# genero
# F        34  34.0  34   12.0  55.0  98.0
# M        11  20.5  30   98.0  98.0  98.0

# %%
# Filtrado de los datos en el que el conjunto no supera una media determinada 
def media(x):
    return x["edad"].mean() > 30

display(frame)
frame.groupby('genero').filter(media)
# Out:
#    nombre  edad  puntos genero  ranking
# 0  Marisa    34    98.0      F      3.0
# 1   Laura    34    12.0      F      1.0
# 2  Manuel    11    98.0      M      3.0
# 3  Carlos    30     NaN      M      NaN
#    nombre  edad  puntos genero  ranking
# 0  Marisa    34    98.0      F      3.0
# 1   Laura    34    12.0      F      1.0

# %% [markdown]
# ## Correlaciones

# %% [markdown]
# pandas incluye métodos para analizar correlaciones
# - Relación matemática entre dos variables (-1 negativamente relacionadas, 1 positivamente relacionadas, 0 sin relación)
# - obj.corr(obj2) --> medida de correlación entre los datos de ambos objetos
# - https://blogs.oracle.com/ai-and-datascience/post/introduction-to-correlation

# %% [markdown]
# ### Ejemplo Fuel efficiency
# - https://archive.ics.uci.edu/ml/datasets/Auto+MPG

# %%
import pandas as pd
path = 'http://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data'

mpg_data = pd.read_csv(path, sep='\s+', header=None,
            names = ['mpg', 'cilindros', 'desplazamiento','potencia',
            'peso', 'aceleracion', 'año', 'origen', 'nombre'],
            na_values='?', engine='c')

# %%
display(mpg_data.sample(5))
# Out:
#       mpg  cilindros  desplazamiento  potencia    peso  aceleracion  año  \
# 43   13.0          8           400.0     170.0  4746.0         12.0   71
# 146  28.0          4            90.0      75.0  2125.0         14.5   74
# 6    14.0          8           454.0     220.0  4354.0          9.0   70
# 300  23.9          8           260.0      90.0  3420.0         22.2   79
# 309  41.5          4            98.0      76.0  2144.0         14.7   80
#
#      origen                             nombre
# 43        1           ford country squire (sw)
# 146       1                         dodge colt
# 6         1                   chevrolet impala
# 300       1  oldsmobile cutlass salon brougham
# 309       2                          vw rabbit

# %%
display(mpg_data.describe(include='all'))
# Out:
#                mpg   cilindros  desplazamiento    potencia         peso  \
# count   398.000000  398.000000      398.000000  392.000000   398.000000
# unique         NaN         NaN             NaN         NaN          NaN
# top            NaN         NaN             NaN         NaN          NaN
# freq           NaN         NaN             NaN         NaN          NaN
# mean     23.514573    5.454774      193.425879  104.469388  2970.424623
# std       7.815984    1.701004      104.269838   38.491160   846.841774
# min       9.000000    3.000000       68.000000   46.000000  1613.000000
# 25%      17.500000    4.000000      104.250000   75.000000  2223.750000
# 50%      23.000000    4.000000      148.500000   93.500000  2803.500000
# 75%      29.000000    8.000000      262.000000  126.000000  3608.000000
# max      46.600000    8.000000      455.000000  230.000000  5140.000000
#
#         aceleracion         año      origen      nombre
# count    398.000000  398.000000  398.000000         398
# unique          NaN         NaN         NaN         305
# top             NaN         NaN         NaN  ford pinto
# freq            NaN         NaN         NaN           6
# mean      15.568090   76.010050    1.572864         NaN
# std        2.757689    3.697627    0.802055         NaN
# min        8.000000   70.000000    1.000000         NaN
# 25%       13.825000   73.000000    1.000000         NaN
# 50%       15.500000   76.000000    1.000000         NaN
# 75%       17.175000   79.000000    2.000000         NaN
# max       24.800000   82.000000    3.000000         NaN

# %%
mpg_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   mpg             398 non-null    float64
#  1   cilindros       398 non-null    int64
#  2   desplazamiento  398 non-null    float64
#  3   potencia        392 non-null    float64
#  4   peso            398 non-null    float64
#  5   aceleracion     398 non-null    float64
#  6   año             398 non-null    int64
#  7   origen          398 non-null    int64
#  8   nombre          398 non-null    object
# dtypes: float64(5), int64(3), object(1)
# memory usage: 28.1+ KB

# %% [markdown]
# ### Correlaciones entre valores

# %%
mpg_data['mpg'].corr(mpg_data['peso']) # + mpg = - peso
# Out:
# np.float64(-0.8317409332443351)

# %%
mpg_data['peso'].corr(mpg_data['aceleracion']) # + peso = - aceleracion
# Out:
# np.float64(-0.4174573199403932)

# %% [markdown]
# ### Correlaciones entre todos los valores

# %%
mpg_data.corr(numeric_only=True)
# Out:
#                      mpg  cilindros  desplazamiento  potencia      peso  \
# mpg             1.000000  -0.775396       -0.804203 -0.778427 -0.831741
# cilindros      -0.775396   1.000000        0.950721  0.842983  0.896017
# desplazamiento -0.804203   0.950721        1.000000  0.897257  0.932824
# potencia       -0.778427   0.842983        0.897257  1.000000  0.864538
# peso           -0.831741   0.896017        0.932824  0.864538  1.000000
# aceleracion     0.420289  -0.505419       -0.543684 -0.689196 -0.417457
# año             0.579267  -0.348746       -0.370164 -0.416361 -0.306564
# origen          0.563450  -0.562543       -0.609409 -0.455171 -0.581024
#
#                 aceleracion       año    origen
# mpg                0.420289  0.579267  0.563450
# cilindros         -0.505419 -0.348746 -0.562543
# desplazamiento    -0.543684 -0.370164 -0.609409
# potencia          -0.689196 -0.416361 -0.455171
# peso              -0.417457 -0.306564 -0.581024
# aceleracion        1.000000  0.288137  0.205873
# año                0.288137  1.000000  0.180662
# origen             0.205873  0.180662  1.000000

# %%
#año y origen no parecen correlacionables
#eliminar columnas de la correlacion
corr_data = mpg_data.drop(['año','origen'],axis=1).corr(numeric_only=True)
display(corr_data)
# Out:
#                      mpg  cilindros  desplazamiento  potencia      peso  \
# mpg             1.000000  -0.775396       -0.804203 -0.778427 -0.831741
# cilindros      -0.775396   1.000000        0.950721  0.842983  0.896017
# desplazamiento -0.804203   0.950721        1.000000  0.897257  0.932824
# potencia       -0.778427   0.842983        0.897257  1.000000  0.864538
# peso           -0.831741   0.896017        0.932824  0.864538  1.000000
# aceleracion     0.420289  -0.505419       -0.543684 -0.689196 -0.417457
#
#                 aceleracion
# mpg                0.420289
# cilindros         -0.505419
# desplazamiento    -0.543684
# potencia          -0.689196
# peso              -0.417457
# aceleracion        1.000000

# %%
# representación gráfica matplotlib
import matplotlib.pyplot as plt

# %%
# representación gráfica
corr_data.style.background_gradient(cmap=plt.get_cmap('RdYlGn'), axis=1)
# Out:
# <style type="text/css">
# #T_0c53a_row0_col0, #T_0c53a_row1_col1, #T_0c53a_row2_col2, #T_0c53a_row3_col3, #T_0c53a_row4_col4, #T_0c53a_row5_col5 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_0c53a_row0_col1, #T_0c53a_row0_col3 {
#   background-color: #b30d26;
#   color: #f1f1f1;
# }
# #T_0c53a_row0_col2 {
#   background-color: #ab0626;
#   color: #f1f1f1;
# }
# #T_0c53a_row0_col4, #T_0c53a_row1_col0, #T_0c53a_row2_col0, #T_0c53a_row3_col0, #T_0c53a_row4_col0, #T_0c53a_row5_col3 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_0c53a_row0_col5 {
#   background-color: #afdd70;
#   color: #000000;
# }
# #T_0c53a_row1_col2 {
#   background-color: #07753e;
#   color: #f1f1f1;
# }
# #T_0c53a_row1_col3, #T_0c53a_row3_col1 {
#   background-color: #16914d;
#   color: #f1f1f1;
# }
# #T_0c53a_row1_col4, #T_0c53a_row2_col3, #T_0c53a_row3_col2, #T_0c53a_row4_col1 {
#   background-color: #0e8245;
#   color: #f1f1f1;
# }
# #T_0c53a_row1_col5 {
#   background-color: #e54e35;
#   color: #f1f1f1;
# }
# #T_0c53a_row2_col1 {
#   background-color: #06733d;
#   color: #f1f1f1;
# }
# #T_0c53a_row2_col4, #T_0c53a_row4_col2 {
#   background-color: #097940;
#   color: #f1f1f1;
# }
# #T_0c53a_row2_col5 {
#   background-color: #e34933;
#   color: #f1f1f1;
# }
# #T_0c53a_row3_col4 {
#   background-color: #138c4a;
#   color: #f1f1f1;
# }
# #T_0c53a_row3_col5 {
#   background-color: #bd1726;
#   color: #f1f1f1;
# }
# #T_0c53a_row4_col3 {
#   background-color: #128a49;
#   color: #f1f1f1;
# }
# #T_0c53a_row4_col5 {
#   background-color: #f67c4a;
#   color: #f1f1f1;
# }
# #T_0c53a_row5_col0 {
#   background-color: #bbe278;
#   color: #000000;
# }
# #T_0c53a_row5_col1 {
#   background-color: #d93429;
#   color: #f1f1f1;
# }
# #T_0c53a_row5_col2 {
#   background-color: #d02927;
#   color: #f1f1f1;
# }
# #T_0c53a_row5_col4 {
#   background-color: #e95538;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_0c53a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0c53a_level0_col0" class="col_heading level0 col0" >mpg</th>
#       <th id="T_0c53a_level0_col1" class="col_heading level0 col1" >cilindros</th>
#       <th id="T_0c53a_level0_col2" class="col_heading level0 col2" >desplazamiento</th>
#       <th id="T_0c53a_level0_col3" class="col_heading level0 col3" >potencia</th>
#       <th id="T_0c53a_level0_col4" class="col_heading level0 col4" >peso</th>
#       <th id="T_0c53a_level0_col5" class="col_heading level0 col5" >aceleracion</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0c53a_level0_row0" class="row_heading level0 row0" >mpg</th>
#       <td id="T_0c53a_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_0c53a_row0_col1" class="data row0 col1" >-0.775396</td>
#       <td id="T_0c53a_row0_col2" class="data row0 col2" >-0.804203</td>
#       <td id="T_0c53a_row0_col3" class="data row0 col3" >-0.778427</td>
#       <td id="T_0c53a_row0_col4" class="data row0 col4" >-0.831741</td>
#       <td id="T_0c53a_row0_col5" class="data row0 col5" >0.420289</td>
#     </tr>
#     <tr>
#       <th id="T_0c53a_level0_row1" class="row_heading level0 row1" >cilindros</th>
#       <td id="T_0c53a_row1_col0" class="data row1 col0" >-0.775396</td>
#       <td id="T_0c53a_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_0c53a_row1_col2" class="data row1 col2" >0.950721</td>
#       <td id="T_0c53a_row1_col3" class="data row1 col3" >0.842983</td>
#       <td id="T_0c53a_row1_col4" class="data row1 col4" >0.896017</td>
#       <td id="T_0c53a_row1_col5" class="data row1 col5" >-0.505419</td>
#     </tr>
#     <tr>
#       <th id="T_0c53a_level0_row2" class="row_heading level0 row2" >desplazamiento</th>
#       <td id="T_0c53a_row2_col0" class="data row2 col0" >-0.804203</td>
#       <td id="T_0c53a_row2_col1" class="data row2 col1" >0.950721</td>
#       <td id="T_0c53a_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_0c53a_row2_col3" class="data row2 col3" >0.897257</td>
#       <td id="T_0c53a_row2_col4" class="data row2 col4" >0.932824</td>
#       <td id="T_0c53a_row2_col5" class="data row2 col5" >-0.543684</td>
#     </tr>
#     <tr>
#       <th id="T_0c53a_level0_row3" class="row_heading level0 row3" >potencia</th>
#       <td id="T_0c53a_row3_col0" class="data row3 col0" >-0.778427</td>
#       <td id="T_0c53a_row3_col1" class="data row3 col1" >0.842983</td>
#       <td id="T_0c53a_row3_col2" class="data row3 col2" >0.897257</td>
#       <td id="T_0c53a_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_0c53a_row3_col4" class="data row3 col4" >0.864538</td>
#       <td id="T_0c53a_row3_col5" class="data row3 col5" >-0.689196</td>
#     </tr>
#     <tr>
#       <th id="T_0c53a_level0_row4" class="row_heading level0 row4" >peso</th>
#       <td id="T_0c53a_row4_col0" class="data row4 col0" >-0.831741</td>
#       <td id="T_0c53a_row4_col1" class="data row4 col1" >0.896017</td>
#       <td id="T_0c53a_row4_col2" class="data row4 col2" >0.932824</td>
#       <td id="T_0c53a_row4_col3" class="data row4 col3" >0.864538</td>
#       <td id="T_0c53a_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_0c53a_row4_col5" class="data row4 col5" >-0.417457</td>
#     </tr>
#     <tr>
#       <th id="T_0c53a_level0_row5" class="row_heading level0 row5" >aceleracion</th>
#       <td id="T_0c53a_row5_col0" class="data row5 col0" >0.420289</td>
#       <td id="T_0c53a_row5_col1" class="data row5 col1" >-0.505419</td>
#       <td id="T_0c53a_row5_col2" class="data row5 col2" >-0.543684</td>
#       <td id="T_0c53a_row5_col3" class="data row5 col3" >-0.689196</td>
#       <td id="T_0c53a_row5_col4" class="data row5 col4" >-0.417457</td>
#       <td id="T_0c53a_row5_col5" class="data row5 col5" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# correlación más negativa
mpg_data.drop(['año','origen'],axis=1).corr(numeric_only=True).idxmin()
# Out:
# mpg                   peso
# cilindros              mpg
# desplazamiento         mpg
# potencia               mpg
# peso                   mpg
# aceleracion       potencia
# dtype: object

# %%
# correlación más positiva
mpg_data.drop(['año','origen'],axis=1).corr(numeric_only=True).idxmax()  #consigo misma....
# Out:
# mpg                          mpg
# cilindros              cilindros
# desplazamiento    desplazamiento
# potencia                potencia
# peso                        peso
# aceleracion          aceleracion
# dtype: object

# %%
# tabla similar con las correlaciones más positivas (evitar parejas del mismo valor)
positive_corr = mpg_data.drop(['año','origen'],axis=1).corr(numeric_only=True)
np.fill_diagonal(positive_corr.values, 0)
display(positive_corr)
positive_corr.idxmax()
# Out:
#                      mpg  cilindros  desplazamiento  potencia      peso  \
# mpg             0.000000  -0.775396       -0.804203 -0.778427 -0.831741
# cilindros      -0.775396   0.000000        0.950721  0.842983  0.896017
# desplazamiento -0.804203   0.950721        0.000000  0.897257  0.932824
# potencia       -0.778427   0.842983        0.897257  0.000000  0.864538
# peso           -0.831741   0.896017        0.932824  0.864538  0.000000
# aceleracion     0.420289  -0.505419       -0.543684 -0.689196 -0.417457
#
#                 aceleracion
# mpg                0.420289
# cilindros         -0.505419
# desplazamiento    -0.543684
# potencia          -0.689196
# peso              -0.417457
# aceleracion        0.000000
# mpg                  aceleracion
# cilindros         desplazamiento
# desplazamiento         cilindros
# potencia          desplazamiento
# peso              desplazamiento
# aceleracion                  mpg
# dtype: object

# %%
positive_corr.style.background_gradient(cmap=plt.get_cmap('RdYlGn'), axis=1, vmin=-1.0, vmax=1.0)
# Out:
# <style type="text/css">
# #T_4e329_row0_col0, #T_4e329_row1_col1, #T_4e329_row2_col2, #T_4e329_row3_col3, #T_4e329_row4_col4, #T_4e329_row5_col5 {
#   background-color: #feffbe;
#   color: #000000;
# }
# #T_4e329_row0_col1, #T_4e329_row0_col3, #T_4e329_row1_col0, #T_4e329_row3_col0 {
#   background-color: #da362a;
#   color: #f1f1f1;
# }
# #T_4e329_row0_col2, #T_4e329_row2_col0 {
#   background-color: #d62f27;
#   color: #f1f1f1;
# }
# #T_4e329_row0_col4, #T_4e329_row4_col0 {
#   background-color: #ce2827;
#   color: #f1f1f1;
# }
# #T_4e329_row0_col5, #T_4e329_row5_col0 {
#   background-color: #a0d669;
#   color: #000000;
# }
# #T_4e329_row1_col2, #T_4e329_row2_col1 {
#   background-color: #06733d;
#   color: #f1f1f1;
# }
# #T_4e329_row1_col3, #T_4e329_row3_col1 {
#   background-color: #148e4b;
#   color: #f1f1f1;
# }
# #T_4e329_row1_col4, #T_4e329_row2_col3, #T_4e329_row3_col2, #T_4e329_row4_col1 {
#   background-color: #0d8044;
#   color: #f1f1f1;
# }
# #T_4e329_row1_col5, #T_4e329_row5_col1 {
#   background-color: #f88c51;
#   color: #f1f1f1;
# }
# #T_4e329_row2_col4, #T_4e329_row4_col2 {
#   background-color: #08773f;
#   color: #f1f1f1;
# }
# #T_4e329_row2_col5, #T_4e329_row5_col2 {
#   background-color: #f67f4b;
#   color: #f1f1f1;
# }
# #T_4e329_row3_col4, #T_4e329_row4_col3 {
#   background-color: #118848;
#   color: #f1f1f1;
# }
# #T_4e329_row3_col5, #T_4e329_row5_col3 {
#   background-color: #e65036;
#   color: #f1f1f1;
# }
# #T_4e329_row4_col5, #T_4e329_row5_col4 {
#   background-color: #fca85e;
#   color: #000000;
# }
# </style>
# <table id="T_4e329">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4e329_level0_col0" class="col_heading level0 col0" >mpg</th>
#       <th id="T_4e329_level0_col1" class="col_heading level0 col1" >cilindros</th>
#       <th id="T_4e329_level0_col2" class="col_heading level0 col2" >desplazamiento</th>
#       <th id="T_4e329_level0_col3" class="col_heading level0 col3" >potencia</th>
#       <th id="T_4e329_level0_col4" class="col_heading level0 col4" >peso</th>
#       <th id="T_4e329_level0_col5" class="col_heading level0 col5" >aceleracion</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4e329_level0_row0" class="row_heading level0 row0" >mpg</th>
#       <td id="T_4e329_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_4e329_row0_col1" class="data row0 col1" >-0.775396</td>
#       <td id="T_4e329_row0_col2" class="data row0 col2" >-0.804203</td>
#       <td id="T_4e329_row0_col3" class="data row0 col3" >-0.778427</td>
#       <td id="T_4e329_row0_col4" class="data row0 col4" >-0.831741</td>
#       <td id="T_4e329_row0_col5" class="data row0 col5" >0.420289</td>
#     </tr>
#     <tr>
#       <th id="T_4e329_level0_row1" class="row_heading level0 row1" >cilindros</th>
#       <td id="T_4e329_row1_col0" class="data row1 col0" >-0.775396</td>
#       <td id="T_4e329_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_4e329_row1_col2" class="data row1 col2" >0.950721</td>
#       <td id="T_4e329_row1_col3" class="data row1 col3" >0.842983</td>
#       <td id="T_4e329_row1_col4" class="data row1 col4" >0.896017</td>
#       <td id="T_4e329_row1_col5" class="data row1 col5" >-0.505419</td>
#     </tr>
#     <tr>
#       <th id="T_4e329_level0_row2" class="row_heading level0 row2" >desplazamiento</th>
#       <td id="T_4e329_row2_col0" class="data row2 col0" >-0.804203</td>
#       <td id="T_4e329_row2_col1" class="data row2 col1" >0.950721</td>
#       <td id="T_4e329_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_4e329_row2_col3" class="data row2 col3" >0.897257</td>
#       <td id="T_4e329_row2_col4" class="data row2 col4" >0.932824</td>
#       <td id="T_4e329_row2_col5" class="data row2 col5" >-0.543684</td>
#     </tr>
#     <tr>
#       <th id="T_4e329_level0_row3" class="row_heading level0 row3" >potencia</th>
#       <td id="T_4e329_row3_col0" class="data row3 col0" >-0.778427</td>
#       <td id="T_4e329_row3_col1" class="data row3 col1" >0.842983</td>
#       <td id="T_4e329_row3_col2" class="data row3 col2" >0.897257</td>
#       <td id="T_4e329_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_4e329_row3_col4" class="data row3 col4" >0.864538</td>
#       <td id="T_4e329_row3_col5" class="data row3 col5" >-0.689196</td>
#     </tr>
#     <tr>
#       <th id="T_4e329_level0_row4" class="row_heading level0 row4" >peso</th>
#       <td id="T_4e329_row4_col0" class="data row4 col0" >-0.831741</td>
#       <td id="T_4e329_row4_col1" class="data row4 col1" >0.896017</td>
#       <td id="T_4e329_row4_col2" class="data row4 col2" >0.932824</td>
#       <td id="T_4e329_row4_col3" class="data row4 col3" >0.864538</td>
#       <td id="T_4e329_row4_col4" class="data row4 col4" >0.000000</td>
#       <td id="T_4e329_row4_col5" class="data row4 col5" >-0.417457</td>
#     </tr>
#     <tr>
#       <th id="T_4e329_level0_row5" class="row_heading level0 row5" >aceleracion</th>
#       <td id="T_4e329_row5_col0" class="data row5 col0" >0.420289</td>
#       <td id="T_4e329_row5_col1" class="data row5 col1" >-0.505419</td>
#       <td id="T_4e329_row5_col2" class="data row5 col2" >-0.543684</td>
#       <td id="T_4e329_row5_col3" class="data row5 col3" >-0.689196</td>
#       <td id="T_4e329_row5_col4" class="data row5 col4" >-0.417457</td>
#       <td id="T_4e329_row5_col5" class="data row5 col5" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Ejercicios

# %% [markdown]
# - Ejercicios para practicar Pandas: https://github.com/ajcr/100-pandas-puzzles/blob/master/100-pandas-puzzles.ipynb

# %%
import numpy as np
#Consider the following Python dictionary data and Python list labels:

data = {'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
        'age': [2.5, 3, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],
        'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}

labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

# %%
import pandas as pd
import numpy as np

# El diccionario de datos proporcionado
data = {
    'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
    'age': [2.5, 3, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],
    'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
    'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']
}

# La lista de etiquetas para el índice
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

# Creación del DataFrame
df = pd.DataFrame(data, index=labels)

# Visualización del resultado
print(df)
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  2.0       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %%
# Mostrar el resumen de información básica
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, a to j
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   animal    10 non-null     object
#  1   age       8 non-null      float64
#  2   visits    10 non-null     int64
#  3   priority  10 non-null     object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 400.0+ bytes

# %%
# 1. Mostrar el resumen técnico (estructura, tipos de datos y nulos)
df.info()

# 2. (Opcional) Mostrar el resumen estadístico de las columnas numéricas
print("\nResumen estadístico:")
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, a to j
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   animal    10 non-null     object
#  1   age       8 non-null      float64
#  2   visits    10 non-null     int64
#  3   priority  10 non-null     object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 400.0+ bytes
#
# Resumen estadístico:
#             age     visits
# count  8.000000  10.000000
# mean   3.437500   1.900000
# std    2.007797   0.875595
# min    0.500000   1.000000
# 25%    2.375000   1.000000
# 50%    3.000000   2.000000
# 75%    4.625000   2.750000
# max    7.000000   3.000000

# %%
# Retornar las primeras 3 filas
primeras_filas = df.head(3)

# Mostrar el resultado
print(primeras_filas)
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no

# %%
# Seleccionar solo las columnas 'animal' y 'age'
seleccion = df[['animal', 'age']]

# Mostrar el resultado
print(seleccion)
# Out:
#   animal  age
# a    cat  2.5
# b    cat  3.0
# c  snake  0.5
# d    dog  NaN
# e    dog  5.0
# f    cat  2.0
# g  snake  4.5
# h    cat  NaN
# i    dog  7.0
# j    dog  3.0

# %%
# Opción 1: Usando las etiquetas de las filas (si conoces que 3, 4, 8 corresponden a d, e, i)
seleccion = df.loc[df.index[[3, 4, 8]], ['animal', 'age']]

# Opción 2: Usando .iloc (basado puramente en posiciones enteras)
# 'animal' es la columna 0 y 'age' es la columna 1
seleccion_posicional = df.iloc[[3, 4, 8], [0, 1]]

print(seleccion)
# Out:
#   animal  age
# d    dog  NaN
# e    dog  5.0
# i    dog  7.0

# %%
# Seleccionar filas donde el número de visitas sea mayor a 3
resultado = df[df['visits'] > 3]

# Mostrar el resultado
print(resultado)
# Out:
# Empty DataFrame
# Columns: [animal, age, visits, priority]
# Index: []

# %%
# Seleccionar las filas donde la edad es NaN (valores perdidos)
filas_con_nan = df[df['age'].isnull()]

# Mostrar el resultado
print(filas_con_nan)
# Out:
#   animal  age  visits priority
# d    dog  NaN       3      yes
# h    cat  NaN       1      yes

# %%
# Seleccionar las filas donde la edad es NaN
filas_sin_edad = df[df['age'].isnull()]

# Mostrar el resultado
print(filas_sin_edad)
# Out:
#   animal  age  visits priority
# d    dog  NaN       3      yes
# h    cat  NaN       1      yes

# %%
# Filtrar filas: animal es 'cat' Y edad es menor que 3
filtro_gatos_jovenes = df[(df['animal'] == 'cat') & (df['age'] < 3)]

# Mostrar el resultado
print(filtro_gatos_jovenes)
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# f    cat  2.0       3       no

# %% [markdown]
# ### [Link Github: Pandas2](https://github.com/moniloag-png/Introduccionpythonnocturno/blob/main/PAO25_25_08_Python_%2BPandas%20.ipynb)
