# %% [markdown]
# # Introducción a Python
# Python es un lenguaje de programación de alto nivel. <br>
# Orientado a objetos

# %%
#Esto es un comentario y voy a imprimir hola mundo Python
#imprimir ("Hola mundo")lo que está dentro de las comillas se llama cadena de caracteres o string
print ("Hola mundo Python")
# Out:
# Hola mundo Python

# %%
print ("Monica Guano")
# Out:
# Monica Guano
